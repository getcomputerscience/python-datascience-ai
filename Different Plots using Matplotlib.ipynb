# %%
#Matplotlib is used for Data Visualization

# %%
import matplotlib

from matplotlib import pyplot as plt 

x = [5, 2, 9, 4, 7] #X-axis

y = [10, 5, 8, 4, 2] #Y-axis

plt.plot(x,y) 

plt.show() #Displaying the plots

# %%
plt.plot([1, 2, 3, 4], [1, 6, 7, 12])

# %%
x = [1, 2, 3, 4, 6]

y = [6, 5, 8, 4, 2] 

plt.scatter(x, y)

plt.show()

# %%
import numpy as np

fig,ax = plt.subplots(1,1)

a = np.array([22, 87, 5, 43, 56, 73, 55, 54, 11, 20, 51, 5, 79, 31, 27]) #List of data.

ax.hist(a, bins = [0, 20, 40, 60, 80, 100]) 

ax.set_title("histogram of result") #Displaying Header of Histogram.

ax.set_xticks([0, 20, 40, 60, 80, 100]) #Displaying the X-axis values.

ax.set_xlabel('marks') #Displaying the X-axis label.

ax.set_ylabel('no. of students') #Displaying the Y-axis label.

plt.show()

# %%
#Bar Graph
from matplotlib import pyplot as plt 
x = [1, 2, 5, 4, 6] 
y = [6, 4, 6, 4, 3]

plt.bar(x,y) #Ploting in Bars 
plt.show()

# %%
names = ['A+', 'A-', 'B+', 'B-', 'O']
values = [98, 23, 75, 12, 63]
plt.bar(names, values)
# Out:
# <BarContainer object of 5 artists>

# %%
#Pie Chart
from matplotlib import pyplot as plt
import numpy as np

fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])

ax.axis('equal')

langs = ['C', 'C++', 'Java', 'Python', 'C#']

students = [23, 17, 35, 53, 12]

ax.pie(students, labels = langs)
plt.show()
